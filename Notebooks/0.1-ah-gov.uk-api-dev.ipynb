# %% [markdown]
# # Prison population of England and Wales

# %% [markdown]
# ## Using Gov.uk Content API to download all weekly prison population data
# https://content-api.publishing.service.gov.uk/

# %% [markdown]
# ## Interacting with API to filter relevant files

# %%
import requests
import pandas as pd

# %%
url = 'https://www.gov.uk/api/content/government/statistics/prison-population-2012'
response = requests.get(url)
response.headers.get("Content-Type")
# Out:
# 'application/json; charset=utf-8'

# %%
response.json()
# Out:
# {'analytics_identifier': None,
#  'base_path': '/government/statistics/prison-population-2012',
#  'content_id': '5dc71785-7631-11e4-a3cb-005056011aef',
#  'description': 'Statistics on the prison population in 2012.\r\n',
#  'details': {'attachments': [{'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 50836,
#     'filename': 'prison-population-monthly-dec2012.doc',
#     'id': '367193',
#     'isbn': '',
#     'title': 'Population bulletin - Monthly December 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7564c840f0b6360e473c50/prison-population-monthly-dec2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-281212.xls',
#     'id': '367194',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 28 December 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c77d8ed915d6969f45155/prison-population-281212.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-211212.xls',
#     'id': '367195',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 21 December 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ca1cae5274a38e5755c58/prison-population-211212.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 49152,
#     'filename': 'prison-population-monthly-nov2012.doc',
#     'id': '367196',
#     'isbn': '',
#     'title': 'Population bulletin - Monthly November 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ca56b40f0b65b3de0a413/prison-population-monthly-nov2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-141212.xls',
#     'id': '367197',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 14 December 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a74ee70ed915d502d6cc273/prison-population-141212.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-071212.xls',
#     'id': '367198',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 07 December 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b7f07ed915d131105f9e1/prison-population-071212.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-301112.xls',
#     'id': '367199',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 30 November 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cd07c40f0b6629523bf9d/prison-population-301112.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-231112.xls',
#     'id': '367200',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 23 November 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a756b83e5274a3edd9a4c6d/prison-population-231112.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-161112.xls',
#     'id': '367201',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 16 November 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c5bf940f0b6601cef574d/prison-population-161112.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-091112.xls',
#     'id': '367202',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 09 November 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c681fe5274a5590059a74/prison-population-091112.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-021112.xls',
#     'id': '367203',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 02 November 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c233b40f0b645ba3c6eb3/prison-population-021112.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 215421,
#     'filename': 'prison-population-monthly-october-2012.doc',
#     'id': '367204',
#     'isbn': '',
#     'title': 'Population bulletin - Monthly October 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b9b67ed915d41476217a9/prison-population-monthly-october-2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-26-10-12.xls',
#     'id': '367205',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 26 October 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c338ae5274a1f5cc76780/prison-population-26-10-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-191012.xls',
#     'id': '367206',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 19 October 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c892440f0b626628acbf5/prison-population-191012.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-121012.xls',
#     'id': '367207',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 12 October 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c3318e5274a1f5cc76746/prison-population-121012.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#     'file_size': 25543,
#     'filename': 'prison-population-monthly-sept2012.docx',
#     'id': '367208',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly September 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c4439e5274a1b004229ab/prison-population-monthly-sept2012.docx'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-051012.xls',
#     'id': '367209',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 05 October 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c9c1540f0b6629523aa11/prison-population-051012.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-280912.xls',
#     'id': '367210',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 28 September 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ba17040f0b62826a04cfc/prison-population-280912.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-210912.xls',
#     'id': '367211',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 21 September 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c925e40f0b62aff6c29c0/prison-population-210912.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-140912.xls',
#     'id': '367212',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 14 September 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b91e9ed915d13110601be/prison-population-140912.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-070912.xls',
#     'id': '367213',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 07 September 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c0be540f0b645ba3c65df/prison-population-070912.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 213402,
#     'filename': 'prison-population-monthly-aug2012.doc',
#     'id': '367214',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly August 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ca1d3e5274a2f304ef15c/prison-population-monthly-aug2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-310812.xls',
#     'id': '367215',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 31 August 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c220a40f0b645ba3c6e3e/prison-population-310812.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-240812.xls',
#     'id': '367216',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 24 August 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b9880ed915d1311060459/prison-population-240812.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-170812.xls',
#     'id': '367217',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 17 August 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c0098ed915d4147622282/prison-population-170812.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#     'file_size': 25572,
#     'filename': 'prison-population-monthly-jul2012.docx',
#     'id': '367218',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly July 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a75902740f0b6397f35f60c/prison-population-monthly-jul2012.docx'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-100812.xls',
#     'id': '367219',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 10 August 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cd83ce5274a2c9a484759/prison-population-100812.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-030812.xls',
#     'id': '367220',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 03 August 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c7390e5274a5590059f4e/prison-population-030812.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-270712.xls',
#     'id': '367221',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 27 July 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c1e1c40f0b61a825d6905/prison-population-270712.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-200712.xls',
#     'id': '367222',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 20 July 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7593d5e5274a545822c986/prison-population-200712.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-13-07-12.xls',
#     'id': '367223',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 13 July 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cd196e5274a2c9a4844cc/prison-population-13-07-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-060712.xls',
#     'id': '367224',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 06 July 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cbc61e5274a2f304efc3f/prison-population-060712.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#     'file_size': 25449,
#     'filename': 'prison-population-monthly-july2012.docx',
#     'id': '367225',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly June 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ca082ed915d6969f46368/prison-population-monthly-july2012.docx'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-290612.xls',
#     'id': '367226',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 29 June 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c75cc40f0b62aff6c1d22/prison-population-290612.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-220612.xls',
#     'id': '367227',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 22 June 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c6b4fed915d6969f44bab/prison-population-220612.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-150612.xls',
#     'id': '367228',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 15 June 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a75c105ed915d506ee813a3/prison-population-150612.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 49152,
#     'filename': 'prison-population-monthly-may2012.doc',
#     'id': '367229',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly May 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cda31e5274a2c9a48482b/prison-population-monthly-may2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-080612.xls',
#     'id': '367230',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 08 June 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b9d05ed915d4147621854/prison-population-080612.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-010612.xls',
#     'id': '367231',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 01 June 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a75a47ced915d506ee80617/prison-population-010612.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-25-may-2012.xls',
#     'id': '367232',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 25 May 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c6ac3e5274a5255bce7fb/prison-population-25-may-2012.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 29696,
#     'filename': 'prison-population-180512.xls',
#     'id': '367233',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 18 May 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cc4c7e5274a2f304eff46/prison-population-180512.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-110512.xls',
#     'id': '367234',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 11 May 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ba89de5274a7318b9015d/prison-population-110512.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 51200,
#     'filename': 'prison-population-monthly-apr2012.doc',
#     'id': '367235',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly April 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c556eed915d338141e1ff/prison-population-monthly-apr2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-040512.xls',
#     'id': '367236',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 04 May 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cbaade5274a38e5756647/prison-population-040512.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-270412.xls',
#     'id': '367237',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 27 April 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a74947ce5274a44083b7d0a/prison-population-270412.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-200412.xls',
#     'id': '367238',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 20 April 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c4617e5274a1b00422a87/prison-population-200412.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-130412.xls',
#     'id': '367239',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 13 April 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cca06e5274a2c9a484209/prison-population-130412.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 51712,
#     'filename': 'prison-population-monthly-mar2012.doc',
#     'id': '367240',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly March 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c1c92e5274a1f5cc75dbe/prison-population-monthly-mar2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-300312.xls',
#     'id': '367241',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 30 March 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a74b84840f0b619c8659e04/prison-population-300312.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-230312.xls',
#     'id': '367242',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 23 March 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c33c640f0b67d0b11f8af/prison-population-230312.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-16-march-2012.xls',
#     'id': '367243',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 16 March 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cdb3540f0b65b3de0b93f/prison-population-16-march-2012.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 52224,
#     'filename': 'prison-population-monthly-feb2012.doc',
#     'id': '367244',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly February 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ba201e5274a7318b8feca/prison-population-monthly-feb2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-090312.xls',
#     'id': '367245',
#     'isbn': '',
#     'title': 'Population bulletin - Weekly 9 March 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cba1840f0b65b3de0acb6/prison-population-090312.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 37376,
#     'filename': 'prison-population-02-03-12.xls',
#     'id': '367246',
#     'isbn': '',
#     'title': 'Population bulletin - Weekly 2 March 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c6f3a40f0b62aff6c1a4f/prison-population-02-03-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28672,
#     'filename': 'prison-population-24-02-12.xls',
#     'id': '367247',
#     'isbn': '',
#     'title': 'Population bulletin - Weekly 24 February 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c238e40f0b645ba3c6ed7/prison-population-24-02-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-17-02-12.xls',
#     'id': '367248',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 17 February 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c526540f0b6321db38681/prison-population-17-02-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-10-02-12.xls',
#     'id': '367249',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 10 February 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b7f90e5274a7202e1790a/prison-population-10-02-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-3-02-12.xls',
#     'id': '367250',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 3 February 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7baa6d40f0b638d61be25c/prison-population-3-02-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/msword',
#     'file_size': 51200,
#     'filename': 'prison-population-monthly-jan-2012.doc',
#     'id': '367251',
#     'isbn': '',
#     'title': 'Population Bulletin - Monthly January 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7ca2e440f0b6629523ad2c/prison-population-monthly-jan-2012.doc'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-27-01-12.xls',
#     'id': '367252',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 27 January 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7c940040f0b626628ad0b2/prison-population-27-01-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-20-01-12.xls',
#     'id': '367253',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 20 January 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7cbf79e5274a2f304efd34/prison-population-20-01-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-13-1-12.xls',
#     'id': '367254',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 13 January 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a75bce540f0b67b3d5c8d4d/prison-population-13-1-12.xls'},
#    {'accessible': False,
#     'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#     'attachment_type': 'file',
#     'command_paper_number': '',
#     'content_type': 'application/vnd.ms-excel',
#     'file_size': 28160,
#     'filename': 'prison-population-06-01-12.xls',
#     'id': '367255',
#     'isbn': '',
#     'title': 'Population Bulletin - Weekly 06 January 2012',
#     'unique_reference': '',
#     'unnumbered_command_paper': False,
#     'unnumbered_hoc_paper': False,
#     'url': 'https://assets.publishing.service.gov.uk/media/5a7b91c040f0b645ba3c52ab/prison-population-06-01-12.xls'}],
#   'body': '<div class="govspeak"><p>Statistics on the prison population in 2012.</p>\n</div>',
#   'change_history': [{'note': 'First published.',
#     'public_timestamp': '2013-01-11T00:00:00.000+00:00'}],
#   'documents': ['<section class="gem-c-attachment govuk-!-display-none-print govuk-!-margin-bottom-6" data-module="ga4-link-tracker">\n  <div class="gem-c-attachment__thumbnail">\n    <a class="govuk-link" target="_self" tabindex="-1" aria-hidden="true" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7564c840f0b6360e473c50/prison-population-monthly-dec2012.doc">\n        <svg class="gem-c-attachment__thumbnail-image gem-c-attachment__thumbnail-image--document" version="1.1" viewBox="0 0 99 140" width="99" height="140" aria-hidden="true">\n  <path d="M12 12h75v27H12zM12 59h9v9h-9zM12 77h9v9h-9zM12 95h9v9h-9zM12 113h9v9h-9zM30 59h57v9H30zM30 77h39v9H30zM30 95h57v9H30zM30 113h48v9H30z" stroke-width="0"/>\n</svg>\n\n</a></div>\n  <div class="gem-c-attachment__details">\n    <h2 class="gem-c-attachment__title">\n      <a class="govuk-link gem-c-attachment__link" target="_self" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7564c840f0b6360e473c50/prison-population-monthly-dec2012.doc">Population bulletin - Monthly December 2012</a>\n</h2>\n\n\n      <p class="gem-c-attachment__metadata"><span class="gem-c-attachment__attribute">MS Word Document</span>, <span class="gem-c-attachment__attribute">49.6 KB</span></p>\n\n\n\n\n      <p class="gem-c-attachment__metadata">This file may not be suitable for users of assistive technology.</p>\n      <details class="gem-c-details govuk-details govuk-!-margin-bottom-3" data-module="govuk-details gem-details ga4-event-tracker">\n  <summary class="govuk-details__summary" data-details-track-click="" data-ga4-event="{&quot;event_name&quot;:&quot;select_content&quot;,&quot;type&quot;:&quot;detail&quot;,&quot;text&quot;:&quot;Request an accessible format.&quot;,&quot;section&quot;:&quot;Request an accessible format.&quot;,&quot;index_section&quot;:1}">\n    <span class="govuk-details__summary-text" data-ga4-expandable>\n      Request an accessible format.\n    </span>\n</summary>  <div class="govuk-details__text">\n    \n        If you use assistive technology (such as a screen reader) and need a version of this document in a more accessible format, please email <a href=\'mailto:web.comments@justice.gov.uk\' target=\'_blank\' class=\'govuk-link\'>web.comments@justice.gov.uk</a>. Please tell us what format you need. It will help us if you say what assistive technology you use.\n\n  </div>\n</details></div></section>',
#    '<section class="gem-c-attachment govuk-!-display-none-print govuk-!-margin-bottom-6" data-module="ga4-link-tracker">\n  <div class="gem-c-attachment__thumbnail">\n    <a class="govuk-link" target="_self" tabindex="-1" aria-hidden="true" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7c77d8ed915d6969f45155/prison-population-281212.xls">\n        <svg class="gem-c-attachment__thumbnail-image gem-c-attachment__thumbnail-image--spreadsheet" version="1.1" viewBox="0 0 99 140" width="99" height="140" aria-hidden="true">\n  <path d="M12 12h75v27H12zm0 47h18.75v63H12zm55 2v59H51V61h16m2-2H49v63h20V59z" stroke-width="0"/>\n  <path d="M49 61.05V120H32.8V61.05H49m2-2H30.75v63H51V59zm34 2V120H69.05V61.05H85m2-2H67v63h20V59z" stroke-width="0"/>\n  <path d="M30 68.5h56.5M30 77.34h56.5M30 112.7h56.5M30 95.02h56.5M30 86.18h56.5M30 103.86h56.5" fill="none" stroke-miterlimit="10" stroke-width="2"/>\n</svg>\n\n</a></div>\n  <div class="gem-c-attachment__details">\n    <h2 class="gem-c-attachment__title">\n      <a class="govuk-link gem-c-attachment__link" target="_self" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7c77d8ed915d6969f45155/prison-population-281212.xls">Population Bulletin - Weekly 28 December 2012</a>\n</h2>\n\n\n      <p class="gem-c-attachment__metadata"><span class="gem-c-attachment__attribute">MS Excel Spreadsheet</span>, <span class="gem-c-attachment__attribute">28 KB</span></p>\n\n\n\n\n      <p class="gem-c-attachment__metadata">This file may not be suitable for users of assistive technology.</p>\n      <details class="gem-c-details govuk-details govuk-!-margin-bottom-3" data-module="govuk-details gem-details ga4-event-tracker">\n  <summary class="govuk-details__summary" data-details-track-click="" data-ga4-event="{&quot;event_name&quot;:&quot;select_content&quot;,&quot;type&quot;:&quot;detail&quot;,&quot;text&quot;:&quot;Request an accessible format.&quot;,&quot;section&quot;:&quot;Request an accessible format.&quot;,&quot;index_section&quot;:2}">\n    <span class="govuk-details__summary-text" data-ga4-expandable>\n      Request an accessible format.\n    </span>\n</summary>  <div class="govuk-details__text">\n    \n        If you use assistive technology (such as a screen reader) and need a version of this document in a more accessible format, please email <a href=\'mailto:web.comments@justice.gov.uk\' target=\'_blank\' class=\'govuk-link\'>web.comments@justice.gov.uk</a>. Please tell us what format you need. It will help us if you say what assistive technology you use.\n\n  </div>\n</details></div></section>',
#    '<section class="gem-c-attachment govuk-!-display-none-print govuk-!-margin-bottom-6" data-module="ga4-link-tracker">\n  <div class="gem-c-attachment__thumbnail">\n    <a class="govuk-link" target="_self" tabindex="-1" aria-hidden="true" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7ca1cae5274a38e5755c58/prison-population-211212.xls">\n        <svg class="gem-c-attachment__thumbnail-image gem-c-attachment__thumbnail-image--spreadsheet" version="1.1" viewBox="0 0 99 140" width="99" height="140" aria-hidden="true">\n  <path d="M12 12h75v27H12zm0 47h18.75v63H12zm55 2v59H51V61h16m2-2H49v63h20V59z" stroke-width="0"/>\n  <path d="M49 61.05V120H32.8V61.05H49m2-2H30.75v63H51V59zm34 2V120H69.05V61.05H85m2-2H67v63h20V59z" stroke-width="0"/>\n  <path d="M30 68.5h56.5M30 77.34h56.5M30 112.7h56.5M30 95.02h56.5M30 86.18h56.5M30 103.86h56.5" fill="none" stroke-miterlimit="10" stroke-width="2"/>\n</svg>\n\n</a></div>\n  <div class="gem-c-attachment__details">\n    <h2 class="gem-c-attachment__title">\n      <a class="govuk-link gem-c-attachment__link" target="_self" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7ca1cae5274a38e5755c58/prison-population-211212.xls">Population Bulletin - Weekly 21 December 2012</a>\n</h2>\n\n\n      <p class="gem-c-attachment__metadata"><span class="gem-c-attachment__attribute">MS Excel Spreadsheet</span>, <span class="gem-c-attachment__attribute">28 KB</span></p>\n\n\n\n\n      <p class="gem-c-attachment__metadata">This file may not be suitable for users of assistive technology.</p>\n      <details class="gem-c-details govuk-details govuk-!-margin-bottom-3" data-module="govuk-details gem-details ga4-event-tracker">\n  <summary class="govuk-details__summary" data-details-track-click="" data-ga4-event="{&quot;event_name&quot;:&quot;select_content&quot;,&quot;type&quot;:&quot;detail&quot;,&quot;text&quot;:&quot;Request an accessible format.&quot;,&quot;section&quot;:&quot;Request an accessible format.&quot;,&quot;index_section&quot;:3}">\n    <span class="govuk-details__summary-text" data-ga4-expandable>\n      Request an accessible format.\n    </span>\n</summary>  <div class="govuk-details__text">\n    \n        If you use assistive technology (such as a screen reader) and need a version of this document in a more accessible format, please email <a href=\'mailto:web.comments@justice.gov.uk\' target=\'_blank\' class=\'govuk-link\'>web.comments@justice.gov.uk</a>. Please tell us what format you need. It will help us if you say what assistive technology you use.\n\n  </div>\n</details></div></section>',
# ...
#    '<section class="gem-c-attachment govuk-!-display-none-print govuk-!-margin-bottom-6" data-module="ga4-link-tracker">\n  <div class="gem-c-attachment__thumbnail">\n    <a class="govuk-link" target="_self" tabindex="-1" aria-hidden="true" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7b91c040f0b645ba3c52ab/prison-population-06-01-12.xls">\n        <svg class="gem-c-attachment__thumbnail-image gem-c-attachment__thumbnail-image--spreadsheet" version="1.1" viewBox="0 0 99 140" width="99" height="140" aria-hidden="true">\n  <path d="M12 12h75v27H12zm0 47h18.75v63H12zm55 2v59H51V61h16m2-2H49v63h20V59z" stroke-width="0"/>\n  <path d="M49 61.05V120H32.8V61.05H49m2-2H30.75v63H51V59zm34 2V120H69.05V61.05H85m2-2H67v63h20V59z" stroke-width="0"/>\n  <path d="M30 68.5h56.5M30 77.34h56.5M30 112.7h56.5M30 95.02h56.5M30 86.18h56.5M30 103.86h56.5" fill="none" stroke-miterlimit="10" stroke-width="2"/>\n</svg>\n\n</a></div>\n  <div class="gem-c-attachment__details">\n    <h2 class="gem-c-attachment__title">\n      <a class="govuk-link gem-c-attachment__link" target="_self" data-ga4-link="{&quot;event_name&quot;:&quot;file_download&quot;,&quot;type&quot;:&quot;attachment&quot;}" href="https://assets.publishing.service.gov.uk/media/5a7b91c040f0b645ba3c52ab/prison-population-06-01-12.xls">Population Bulletin - Weekly 06 January 2012</a>\n</h2>\n\n\n      <p class="gem-c-attachment__metadata"><span class="gem-c-attachment__attribute">MS Excel Spreadsheet</span>, <span class="gem-c-attachment__attribute">27.5 KB</span></p>\n\n\n\n\n      <p class="gem-c-attachment__metadata">This file may not be suitable for users of assistive technology.</p>\n      <details class="gem-c-details govuk-details govuk-!-margin-bottom-3" data-module="govuk-details gem-details ga4-event-tracker">\n  <summary class="govuk-details__summary" data-details-track-click="" data-ga4-event="{&quot;event_name&quot;:&quot;select_content&quot;,&quot;type&quot;:&quot;detail&quot;,&quot;text&quot;:&quot;Request an accessible format.&quot;,&quot;section&quot;:&quot;Request an accessible format.&quot;,&quot;index_section&quot;:63}">\n    <span class="govuk-details__summary-text" data-ga4-expandable>\n      Request an accessible format.\n    </span>\n</summary>  <div class="govuk-details__text">\n    \n        If you use assistive technology (such as a screen reader) and need a version of this document in a more accessible format, please email <a href=\'mailto:web.comments@justice.gov.uk\' target=\'_blank\' class=\'govuk-link\'>web.comments@justice.gov.uk</a>. Please tell us what format you need. It will help us if you say what assistive technology you use.\n\n  </div>\n</details></div></section>'],
#   'emphasised_organisations': ['dcc907d6-433c-42df-9ffb-d9c68be5dc4d'],
#   'featured_attachments': ['367193',
#    '367194',
#    '367195',
#    '367196',
#    '367197',
#    '367198',
#    '367199',
#    '367200',
#    '367201',
#    '367202',
#    '367203',
#    '367204',
#    '367205',
#    '367206',
#    '367207',
#    '367208',
#    '367209',
#    '367210',
#    '367211',
#    '367212',
#    '367213',
#    '367214',
#    '367215',
#    '367216',
#    '367217',
#    '367218',
#    '367219',
#    '367220',
#    '367221',
#    '367222',
#    '367223',
#    '367224',
#    '367225',
#    '367226',
#    '367227',
#    '367228',
#    '367229',
#    '367230',
#    '367231',
#    '367232',
#    '367233',
#    '367234',
#    '367235',
#    '367236',
#    '367237',
#    '367238',
#    '367239',
#    '367240',
#    '367241',
#    '367242',
#    '367243',
#    '367244',
#    '367245',
#    '367246',
#    '367247',
#    '367248',
#    '367249',
#    '367250',
#    '367251',
#    '367252',
#    '367253',
#    '367254',
#    '367255'],
#   'first_public_at': '2013-01-11T00:00:00.000+00:00',
#   'political': False,
#   'tags': {'browse_pages': []}},
#  'document_type': 'official_statistics',
#  'first_published_at': '2013-01-11T00:00:00+00:00',
#  'links': {'available_translations': [{'api_path': '/api/content/government/statistics/prison-population-2012',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2012',
#     'base_path': '/government/statistics/prison-population-2012',
#     'content_id': '5dc71785-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2013-01-11T00:00:00Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2012',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-2012',
#     'withdrawn': False}],
#   'document_collections': [{'api_path': '/api/content/government/collections/prison-population-statistics',
#     'api_url': 'https://www.gov.uk/api/content/government/collections/prison-population-statistics',
#     'base_path': '/government/collections/prison-population-statistics',
#     'content_id': '5eb8ebe9-7631-11e4-a3cb-005056011aef',
#     'document_type': 'document_collection',
#     'links': {'documents': [{'api_path': '/api/content/government/statistics/prison-population-2012',
#        'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2012',
#        'base_path': '/government/statistics/prison-population-2012',
#        'content_id': '5dc71785-7631-11e4-a3cb-005056011aef',
#        'document_type': 'official_statistics',
#        'links': {},
#        'locale': 'en',
#        'public_updated_at': '2013-01-11T00:00:00Z',
#        'schema_name': 'publication',
#        'title': 'Prison population figures: 2012',
#        'web_url': 'https://www.gov.uk/government/statistics/prison-population-2012',
#        'withdrawn': False}]},
#     'locale': 'en',
#     'public_updated_at': '2025-01-06T15:18:12Z',
#     'schema_name': 'document_collection',
#     'title': 'Prison population statistics',
#     'web_url': 'https://www.gov.uk/government/collections/prison-population-statistics',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/collections/prisons-and-probation-statistics',
#     'api_url': 'https://www.gov.uk/api/content/government/collections/prisons-and-probation-statistics',
#     'base_path': '/government/collections/prisons-and-probation-statistics',
#     'content_id': '5eb7b921-7631-11e4-a3cb-005056011aef',
#     'document_type': 'document_collection',
#     'links': {'documents': [{'api_path': '/api/content/government/statistics/prison-population-2012',
#        'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2012',
#        'base_path': '/government/statistics/prison-population-2012',
#        'content_id': '5dc71785-7631-11e4-a3cb-005056011aef',
#        'document_type': 'official_statistics',
#        'links': {},
#        'locale': 'en',
#        'public_updated_at': '2013-01-11T00:00:00Z',
#        'schema_name': 'publication',
#        'title': 'Prison population figures: 2012',
#        'web_url': 'https://www.gov.uk/government/statistics/prison-population-2012',
#        'withdrawn': False}]},
#     'locale': 'en',
#     'public_updated_at': '2018-01-25T09:30:47Z',
#     'schema_name': 'document_collection',
#     'title': 'Prisons and probation statistics',
#     'web_url': 'https://www.gov.uk/government/collections/prisons-and-probation-statistics',
#     'withdrawn': False}],
#   'government': [{'api_path': '/api/content/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government',
#     'api_url': 'https://www.gov.uk/api/content/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government',
#     'base_path': '/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government',
#     'content_id': '591c83aa-3b74-437d-a342-612bddd97572',
#     'details': {'current': False,
#      'ended_on': '2015-05-08T00:00:00+00:00',
#      'started_on': '2010-05-12T00:00:00+00:00'},
#     'document_type': 'government',
#     'links': {},
#     'locale': 'en',
#     'title': '2010 to 2015 Conservative and Liberal Democrat coalition government',
#     'web_url': 'https://www.gov.uk/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government'}],
#   'organisations': [{'analytics_identifier': 'D18',
#     'api_path': '/api/content/government/organisations/ministry-of-justice',
#     'api_url': 'https://www.gov.uk/api/content/government/organisations/ministry-of-justice',
#     'base_path': '/government/organisations/ministry-of-justice',
#     'content_id': 'dcc907d6-433c-42df-9ffb-d9c68be5dc4d',
#     'details': {'acronym': 'MOJ',
#      'brand': 'ministry-of-justice',
#      'default_news_image': {'high_resolution_url': 'https://assets.publishing.service.gov.uk/media/5a37db21ed915d5a62fdc762/s960_ministry-of-justice.jpg',
#       'url': 'https://assets.publishing.service.gov.uk/media/5a37db21e5274a7908e352d9/s300_ministry-of-justice.jpg'},
#      'logo': {'crest': 'single-identity',
#       'formatted_title': 'Ministry<br/>of Justice'},
#      'organisation_govuk_status': {'status': 'live',
#       'updated_at': None,
#       'url': None}},
#     'document_type': 'organisation',
#     'links': {},
#     'locale': 'en',
#     'schema_name': 'organisation',
#     'title': 'Ministry of Justice',
#     'web_url': 'https://www.gov.uk/government/organisations/ministry-of-justice',
#     'withdrawn': False}],
#   'original_primary_publishing_organisation': [{'analytics_identifier': 'D18',
#     'api_path': '/api/content/government/organisations/ministry-of-justice',
#     'api_url': 'https://www.gov.uk/api/content/government/organisations/ministry-of-justice',
#     'base_path': '/government/organisations/ministry-of-justice',
#     'content_id': 'dcc907d6-433c-42df-9ffb-d9c68be5dc4d',
#     'details': {'acronym': 'MOJ',
#      'brand': 'ministry-of-justice',
#      'default_news_image': {'high_resolution_url': 'https://assets.publishing.service.gov.uk/media/5a37db21ed915d5a62fdc762/s960_ministry-of-justice.jpg',
#       'url': 'https://assets.publishing.service.gov.uk/media/5a37db21e5274a7908e352d9/s300_ministry-of-justice.jpg'},
#      'logo': {'crest': 'single-identity',
#       'formatted_title': 'Ministry<br/>of Justice'},
#      'organisation_govuk_status': {'status': 'live',
#       'updated_at': None,
#       'url': None}},
#     'document_type': 'organisation',
#     'links': {},
#     'locale': 'en',
#     'schema_name': 'organisation',
#     'title': 'Ministry of Justice',
#     'web_url': 'https://www.gov.uk/government/organisations/ministry-of-justice',
#     'withdrawn': False}],
#   'primary_publishing_organisation': [{'analytics_identifier': 'D18',
#     'api_path': '/api/content/government/organisations/ministry-of-justice',
#     'api_url': 'https://www.gov.uk/api/content/government/organisations/ministry-of-justice',
#     'base_path': '/government/organisations/ministry-of-justice',
#     'content_id': 'dcc907d6-433c-42df-9ffb-d9c68be5dc4d',
#     'details': {'acronym': 'MOJ',
#      'brand': 'ministry-of-justice',
#      'default_news_image': {'high_resolution_url': 'https://assets.publishing.service.gov.uk/media/5a37db21ed915d5a62fdc762/s960_ministry-of-justice.jpg',
#       'url': 'https://assets.publishing.service.gov.uk/media/5a37db21e5274a7908e352d9/s300_ministry-of-justice.jpg'},
#      'logo': {'crest': 'single-identity',
#       'formatted_title': 'Ministry<br/>of Justice'},
#      'organisation_govuk_status': {'status': 'live',
#       'updated_at': None,
#       'url': None}},
#     'document_type': 'organisation',
#     'links': {},
#     'locale': 'en',
#     'schema_name': 'organisation',
#     'title': 'Ministry of Justice',
#     'web_url': 'https://www.gov.uk/government/organisations/ministry-of-justice',
#     'withdrawn': False}],
#   'suggested_ordered_related_items': [{'api_path': '/api/content/government/statistics/prison-population-figures-2016',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2016',
#     'base_path': '/government/statistics/prison-population-figures-2016',
#     'content_id': 'a2317d16-012d-4aa4-9f32-b3c281b14364',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2017-01-13T10:29:32Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2016',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2016',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-2011',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2011',
#     'base_path': '/government/statistics/prison-population-2011',
#     'content_id': '5dc716fe-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2012-12-28T00:00:00Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2011',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-2011',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/population-in-custody',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/population-in-custody',
#     'base_path': '/government/statistics/population-in-custody',
#     'content_id': '5dc71616-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2010-09-30T00:00:00Z',
#     'schema_name': 'publication',
#     'title': 'Population in custody: Jan 2009 to Aug 2010',
#     'web_url': 'https://www.gov.uk/government/statistics/population-in-custody',
#     'withdrawn': False}],
#   'taxons': [{'api_path': '/api/content/crime-justice-and-law/justice-system-transparency',
#     'api_url': 'https://www.gov.uk/api/content/crime-justice-and-law/justice-system-transparency',
#     'base_path': '/crime-justice-and-law/justice-system-transparency',
#     'content_id': 'afd65c1c-dee0-4f5b-8bd6-4f502e4870af',
#     'details': {'internal_name': 'Justice system transparency [P]',
#      'notes_for_editors': '',
#      'visible_to_departmental_editors': False},
#     'document_type': 'taxon',
#     'links': {'parent_taxons': [{'api_path': '/api/content/crime-justice-and-law',
#        'api_url': 'https://www.gov.uk/api/content/crime-justice-and-law',
#        'base_path': '/crime-justice-and-law',
#        'content_id': 'ba951b09-5146-43be-87af-44075eac3ae9',
#        'description': '',
#        'details': {'internal_name': 'Crime, justice and law',
#         'notes_for_editors': '',
#         'visible_to_departmental_editors': True},
#        'document_type': 'taxon',
#        'links': {'root_taxon': [{'api_path': '/api/content/',
#           'api_url': 'https://www.gov.uk/api/content/',
#           'base_path': '/',
#           'content_id': 'f3bbdec2-0e62-4520-a7fd-6ffd5d36e03a',
#           'document_type': 'homepage',
#           'links': {},
#           'locale': 'en',
#           'public_updated_at': '2023-06-28T09:32:34Z',
#           'schema_name': 'homepage',
#           'title': 'GOV.UK homepage',
#           'web_url': 'https://www.gov.uk/',
#           'withdrawn': False}]},
#        'locale': 'en',
#        'phase': 'live',
#        'public_updated_at': '2018-09-16T20:34:51Z',
#        'schema_name': 'taxon',
#        'title': 'Crime, justice and law',
#        'web_url': 'https://www.gov.uk/crime-justice-and-law',
#        'withdrawn': False}]},
#     'locale': 'en',
#     'phase': 'live',
#     'public_updated_at': '2018-09-05T16:15:52Z',
#     'schema_name': 'taxon',
#     'title': 'Justice system transparency',
#     'web_url': 'https://www.gov.uk/crime-justice-and-law/justice-system-transparency',
#     'withdrawn': False}]},
#  'locale': 'en',
#  'phase': 'live',
#  'public_updated_at': '2013-01-11T00:00:00+00:00',
#  'publishing_app': 'whitehall',
#  'publishing_request_id': '21-1713891314.118-10.13.33.117-628',
#  'publishing_scheduled_at': None,
#  'rendering_app': 'government-frontend',
#  'scheduled_publishing_delay_seconds': None,
#  'schema_name': 'publication',
#  'title': 'Prison population figures: 2012',
#  'updated_at': '2025-01-06T15:18:12+00:00',
#  'withdrawn_notice': {}}

# %%
response.json()['details']['attachments']
# Out:
# [{'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 50836,
#   'filename': 'prison-population-monthly-dec2012.doc',
#   'id': '367193',
#   'isbn': '',
#   'title': 'Population bulletin - Monthly December 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7564c840f0b6360e473c50/prison-population-monthly-dec2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-281212.xls',
#   'id': '367194',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 28 December 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c77d8ed915d6969f45155/prison-population-281212.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-211212.xls',
#   'id': '367195',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 21 December 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ca1cae5274a38e5755c58/prison-population-211212.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 49152,
#   'filename': 'prison-population-monthly-nov2012.doc',
#   'id': '367196',
#   'isbn': '',
#   'title': 'Population bulletin - Monthly November 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ca56b40f0b65b3de0a413/prison-population-monthly-nov2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-141212.xls',
#   'id': '367197',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 14 December 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a74ee70ed915d502d6cc273/prison-population-141212.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-071212.xls',
#   'id': '367198',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 07 December 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b7f07ed915d131105f9e1/prison-population-071212.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-301112.xls',
#   'id': '367199',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 30 November 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cd07c40f0b6629523bf9d/prison-population-301112.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-231112.xls',
#   'id': '367200',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 23 November 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a756b83e5274a3edd9a4c6d/prison-population-231112.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-161112.xls',
#   'id': '367201',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 16 November 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c5bf940f0b6601cef574d/prison-population-161112.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-091112.xls',
#   'id': '367202',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 09 November 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c681fe5274a5590059a74/prison-population-091112.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-021112.xls',
#   'id': '367203',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 02 November 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c233b40f0b645ba3c6eb3/prison-population-021112.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 215421,
#   'filename': 'prison-population-monthly-october-2012.doc',
#   'id': '367204',
#   'isbn': '',
#   'title': 'Population bulletin - Monthly October 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b9b67ed915d41476217a9/prison-population-monthly-october-2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-26-10-12.xls',
#   'id': '367205',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 26 October 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c338ae5274a1f5cc76780/prison-population-26-10-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-191012.xls',
#   'id': '367206',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 19 October 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c892440f0b626628acbf5/prison-population-191012.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-121012.xls',
#   'id': '367207',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 12 October 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c3318e5274a1f5cc76746/prison-population-121012.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'file_size': 25543,
#   'filename': 'prison-population-monthly-sept2012.docx',
#   'id': '367208',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly September 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c4439e5274a1b004229ab/prison-population-monthly-sept2012.docx'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-051012.xls',
#   'id': '367209',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 05 October 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c9c1540f0b6629523aa11/prison-population-051012.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-280912.xls',
#   'id': '367210',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 28 September 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ba17040f0b62826a04cfc/prison-population-280912.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-210912.xls',
#   'id': '367211',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 21 September 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c925e40f0b62aff6c29c0/prison-population-210912.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-140912.xls',
#   'id': '367212',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 14 September 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b91e9ed915d13110601be/prison-population-140912.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-070912.xls',
#   'id': '367213',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 07 September 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c0be540f0b645ba3c65df/prison-population-070912.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 213402,
#   'filename': 'prison-population-monthly-aug2012.doc',
#   'id': '367214',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly August 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ca1d3e5274a2f304ef15c/prison-population-monthly-aug2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-310812.xls',
#   'id': '367215',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 31 August 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c220a40f0b645ba3c6e3e/prison-population-310812.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-240812.xls',
#   'id': '367216',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 24 August 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b9880ed915d1311060459/prison-population-240812.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-170812.xls',
#   'id': '367217',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 17 August 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c0098ed915d4147622282/prison-population-170812.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'file_size': 25572,
#   'filename': 'prison-population-monthly-jul2012.docx',
#   'id': '367218',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly July 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a75902740f0b6397f35f60c/prison-population-monthly-jul2012.docx'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-100812.xls',
#   'id': '367219',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 10 August 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cd83ce5274a2c9a484759/prison-population-100812.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-030812.xls',
#   'id': '367220',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 03 August 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c7390e5274a5590059f4e/prison-population-030812.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-270712.xls',
#   'id': '367221',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 27 July 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c1e1c40f0b61a825d6905/prison-population-270712.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-200712.xls',
#   'id': '367222',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 20 July 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7593d5e5274a545822c986/prison-population-200712.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-13-07-12.xls',
#   'id': '367223',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 13 July 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cd196e5274a2c9a4844cc/prison-population-13-07-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-060712.xls',
#   'id': '367224',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 06 July 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cbc61e5274a2f304efc3f/prison-population-060712.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'file_size': 25449,
#   'filename': 'prison-population-monthly-july2012.docx',
#   'id': '367225',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly June 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ca082ed915d6969f46368/prison-population-monthly-july2012.docx'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-290612.xls',
#   'id': '367226',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 29 June 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c75cc40f0b62aff6c1d22/prison-population-290612.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-220612.xls',
#   'id': '367227',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 22 June 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c6b4fed915d6969f44bab/prison-population-220612.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-150612.xls',
#   'id': '367228',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 15 June 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a75c105ed915d506ee813a3/prison-population-150612.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 49152,
#   'filename': 'prison-population-monthly-may2012.doc',
#   'id': '367229',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly May 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cda31e5274a2c9a48482b/prison-population-monthly-may2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-080612.xls',
#   'id': '367230',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 08 June 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b9d05ed915d4147621854/prison-population-080612.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-010612.xls',
#   'id': '367231',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 01 June 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a75a47ced915d506ee80617/prison-population-010612.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-25-may-2012.xls',
#   'id': '367232',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 25 May 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c6ac3e5274a5255bce7fb/prison-population-25-may-2012.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 29696,
#   'filename': 'prison-population-180512.xls',
#   'id': '367233',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 18 May 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cc4c7e5274a2f304eff46/prison-population-180512.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-110512.xls',
#   'id': '367234',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 11 May 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ba89de5274a7318b9015d/prison-population-110512.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 51200,
#   'filename': 'prison-population-monthly-apr2012.doc',
#   'id': '367235',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly April 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c556eed915d338141e1ff/prison-population-monthly-apr2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-040512.xls',
#   'id': '367236',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 04 May 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cbaade5274a38e5756647/prison-population-040512.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-270412.xls',
#   'id': '367237',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 27 April 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a74947ce5274a44083b7d0a/prison-population-270412.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-200412.xls',
#   'id': '367238',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 20 April 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c4617e5274a1b00422a87/prison-population-200412.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-130412.xls',
#   'id': '367239',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 13 April 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cca06e5274a2c9a484209/prison-population-130412.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 51712,
#   'filename': 'prison-population-monthly-mar2012.doc',
#   'id': '367240',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly March 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c1c92e5274a1f5cc75dbe/prison-population-monthly-mar2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-300312.xls',
#   'id': '367241',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 30 March 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a74b84840f0b619c8659e04/prison-population-300312.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-230312.xls',
#   'id': '367242',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 23 March 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c33c640f0b67d0b11f8af/prison-population-230312.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-16-march-2012.xls',
#   'id': '367243',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 16 March 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cdb3540f0b65b3de0b93f/prison-population-16-march-2012.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 52224,
#   'filename': 'prison-population-monthly-feb2012.doc',
#   'id': '367244',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly February 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ba201e5274a7318b8feca/prison-population-monthly-feb2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-090312.xls',
#   'id': '367245',
#   'isbn': '',
#   'title': 'Population bulletin - Weekly 9 March 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cba1840f0b65b3de0acb6/prison-population-090312.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 37376,
#   'filename': 'prison-population-02-03-12.xls',
#   'id': '367246',
#   'isbn': '',
#   'title': 'Population bulletin - Weekly 2 March 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c6f3a40f0b62aff6c1a4f/prison-population-02-03-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28672,
#   'filename': 'prison-population-24-02-12.xls',
#   'id': '367247',
#   'isbn': '',
#   'title': 'Population bulletin - Weekly 24 February 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c238e40f0b645ba3c6ed7/prison-population-24-02-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-17-02-12.xls',
#   'id': '367248',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 17 February 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c526540f0b6321db38681/prison-population-17-02-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-10-02-12.xls',
#   'id': '367249',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 10 February 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b7f90e5274a7202e1790a/prison-population-10-02-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-3-02-12.xls',
#   'id': '367250',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 3 February 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7baa6d40f0b638d61be25c/prison-population-3-02-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/msword',
#   'file_size': 51200,
#   'filename': 'prison-population-monthly-jan-2012.doc',
#   'id': '367251',
#   'isbn': '',
#   'title': 'Population Bulletin - Monthly January 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7ca2e440f0b6629523ad2c/prison-population-monthly-jan-2012.doc'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-27-01-12.xls',
#   'id': '367252',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 27 January 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7c940040f0b626628ad0b2/prison-population-27-01-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-20-01-12.xls',
#   'id': '367253',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 20 January 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7cbf79e5274a2f304efd34/prison-population-20-01-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-13-1-12.xls',
#   'id': '367254',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 13 January 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a75bce540f0b67b3d5c8d4d/prison-population-13-1-12.xls'},
#  {'accessible': False,
#   'alternative_format_contact_email': 'web.comments@justice.gov.uk',
#   'attachment_type': 'file',
#   'command_paper_number': '',
#   'content_type': 'application/vnd.ms-excel',
#   'file_size': 28160,
#   'filename': 'prison-population-06-01-12.xls',
#   'id': '367255',
#   'isbn': '',
#   'title': 'Population Bulletin - Weekly 06 January 2012',
#   'unique_reference': '',
#   'unnumbered_command_paper': False,
#   'unnumbered_hoc_paper': False,
#   'url': 'https://assets.publishing.service.gov.uk/media/5a7b91c040f0b645ba3c52ab/prison-population-06-01-12.xls'}]

# %%
attachments = response.json()['details']['attachments']

# Exclude Word document content types
spreadsheet_attachments = [
    attachment['url'] for attachment in attachments
    if attachment.get('content_type') not in {
        'application/msword',
        'application/vnd.openxmlformats-officedocument.wordprocessingml.document'
    }
]

# %%
spreadsheet_attachments
# Out:
# ['https://assets.publishing.service.gov.uk/media/5a7c77d8ed915d6969f45155/prison-population-281212.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7ca1cae5274a38e5755c58/prison-population-211212.xls',
#  'https://assets.publishing.service.gov.uk/media/5a74ee70ed915d502d6cc273/prison-population-141212.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7b7f07ed915d131105f9e1/prison-population-071212.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cd07c40f0b6629523bf9d/prison-population-301112.xls',
#  'https://assets.publishing.service.gov.uk/media/5a756b83e5274a3edd9a4c6d/prison-population-231112.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c5bf940f0b6601cef574d/prison-population-161112.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c681fe5274a5590059a74/prison-population-091112.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c233b40f0b645ba3c6eb3/prison-population-021112.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c338ae5274a1f5cc76780/prison-population-26-10-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c892440f0b626628acbf5/prison-population-191012.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c3318e5274a1f5cc76746/prison-population-121012.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c9c1540f0b6629523aa11/prison-population-051012.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7ba17040f0b62826a04cfc/prison-population-280912.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c925e40f0b62aff6c29c0/prison-population-210912.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7b91e9ed915d13110601be/prison-population-140912.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c0be540f0b645ba3c65df/prison-population-070912.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c220a40f0b645ba3c6e3e/prison-population-310812.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7b9880ed915d1311060459/prison-population-240812.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c0098ed915d4147622282/prison-population-170812.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cd83ce5274a2c9a484759/prison-population-100812.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c7390e5274a5590059f4e/prison-population-030812.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c1e1c40f0b61a825d6905/prison-population-270712.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7593d5e5274a545822c986/prison-population-200712.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cd196e5274a2c9a4844cc/prison-population-13-07-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cbc61e5274a2f304efc3f/prison-population-060712.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c75cc40f0b62aff6c1d22/prison-population-290612.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c6b4fed915d6969f44bab/prison-population-220612.xls',
#  'https://assets.publishing.service.gov.uk/media/5a75c105ed915d506ee813a3/prison-population-150612.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7b9d05ed915d4147621854/prison-population-080612.xls',
#  'https://assets.publishing.service.gov.uk/media/5a75a47ced915d506ee80617/prison-population-010612.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c6ac3e5274a5255bce7fb/prison-population-25-may-2012.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cc4c7e5274a2f304eff46/prison-population-180512.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7ba89de5274a7318b9015d/prison-population-110512.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cbaade5274a38e5756647/prison-population-040512.xls',
#  'https://assets.publishing.service.gov.uk/media/5a74947ce5274a44083b7d0a/prison-population-270412.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c4617e5274a1b00422a87/prison-population-200412.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cca06e5274a2c9a484209/prison-population-130412.xls',
#  'https://assets.publishing.service.gov.uk/media/5a74b84840f0b619c8659e04/prison-population-300312.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c33c640f0b67d0b11f8af/prison-population-230312.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cdb3540f0b65b3de0b93f/prison-population-16-march-2012.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cba1840f0b65b3de0acb6/prison-population-090312.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c6f3a40f0b62aff6c1a4f/prison-population-02-03-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c238e40f0b645ba3c6ed7/prison-population-24-02-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c526540f0b6321db38681/prison-population-17-02-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7b7f90e5274a7202e1790a/prison-population-10-02-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7baa6d40f0b638d61be25c/prison-population-3-02-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7c940040f0b626628ad0b2/prison-population-27-01-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7cbf79e5274a2f304efd34/prison-population-20-01-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a75bce540f0b67b3d5c8d4d/prison-population-13-1-12.xls',
#  'https://assets.publishing.service.gov.uk/media/5a7b91c040f0b645ba3c52ab/prison-population-06-01-12.xls']

# %% [markdown]
# Great, that has filtered the list to only show spreadsheets. Now to attempt to download

# %% [markdown]
# ## File download development

# %%
from concurrent.futures import ThreadPoolExecutor
import requests
import os

# %%
url = 'https://www.gov.uk/api/content/government/statistics/prison-population-2012'

# %%
def download_file(url, path='data/raw/'):
    response = requests.get(url)
    data = response.json()
    year = data['base_path'].split('-')[-1]
    attachments = response.json()['details']['attachments']

    # Exclude Word document content types
    spreadsheet_attachments = [
        attachment['url'] for attachment in attachments
        if attachment.get('content_type') not in {
            'application/msword',
            'application/vnd.openxmlformats-officedocument.wordprocessingml.document'
        }
    ]

    for spreadsheet_url in spreadsheet_attachments:
        # Make a GET request to download the spreadsheet file
        spreadsheet_response = requests.get(spreadsheet_url)
        # Extracting the filename from the URL
        filename = path + year + spreadsheet_url.split('/')[-1]
        # Save the spreadsheet content to a local file
        with open(filename, 'wb') as file:
            file.write(spreadsheet_response.content)
        print(f"Downloaded file {filename.split('/')[-1]}")

# %%
download_file(url=url)
# Out:
# Downloaded file data/raw/test/prison-population-06-01-12.xls

# %% [markdown]
# Great, that's downloaded a year's worth of data. It would be helpful to separate this out into a year folder. Having investigated the `response.json()` it would seem that `base_path` is probably the most reliable attribute to use for this.

# %%
response.json()['base_path']
# Out:
# '/government/statistics/prison-population-2012'

# %%
response.json()['base_path'].split('-')[-1]
# Out:
# '2012'

# %% [markdown]
# Redefining the function to include the year folder logic and using `os.makedirs()` and `os.path.join()`

# %%
def download_file(url, path='data/raw/'):
    response = requests.get(url)
    data = response.json()
    year = data['base_path'].split('-')[-1]
    attachments = data['details']['attachments']

    # Exclude Word document content types
    spreadsheet_attachments = [
        attachment['url'] for attachment in attachments
        if attachment.get('content_type') not in {
            'application/msword',
            'application/vnd.openxmlformats-officedocument.wordprocessingml.document'
        }
    ]

    # Define the full directory path with the year subfolder
    year_path = os.path.join(path, year)
    os.makedirs(year_path, exist_ok=True)  # Ensure the directory exists

    for spreadsheet_url in spreadsheet_attachments:
        # Make a GET request to download the spreadsheet file
        spreadsheet_response = requests.get(spreadsheet_url)
        
        # Extract the filename from the URL
        filename = os.path.join(year_path, spreadsheet_url.split('/')[-1])
        
        # Save the spreadsheet content to a local file
        with open(filename, 'wb') as file:
            file.write(spreadsheet_response.content)
        
        print(f"Downloaded file {os.path.basename(filename)} to {year_path}/")
    print("Download complete!")

# %%
download_file(url=url)
# Out:
# Downloaded file prison-population-281212.xls to data/raw/2012/
# Downloaded file prison-population-211212.xls to data/raw/2012/
# Downloaded file prison-population-141212.xls to data/raw/2012/
# Downloaded file prison-population-071212.xls to data/raw/2012/
# Downloaded file prison-population-301112.xls to data/raw/2012/
# Downloaded file prison-population-231112.xls to data/raw/2012/
# Downloaded file prison-population-161112.xls to data/raw/2012/
# Downloaded file prison-population-091112.xls to data/raw/2012/
# Downloaded file prison-population-021112.xls to data/raw/2012/
# Downloaded file prison-population-26-10-12.xls to data/raw/2012/
# Downloaded file prison-population-191012.xls to data/raw/2012/
# Downloaded file prison-population-121012.xls to data/raw/2012/
# Downloaded file prison-population-051012.xls to data/raw/2012/
# Downloaded file prison-population-280912.xls to data/raw/2012/
# Downloaded file prison-population-210912.xls to data/raw/2012/
# Downloaded file prison-population-140912.xls to data/raw/2012/
# Downloaded file prison-population-070912.xls to data/raw/2012/
# Downloaded file prison-population-310812.xls to data/raw/2012/
# Downloaded file prison-population-240812.xls to data/raw/2012/
# Downloaded file prison-population-170812.xls to data/raw/2012/
# Downloaded file prison-population-100812.xls to data/raw/2012/
# Downloaded file prison-population-030812.xls to data/raw/2012/
# Downloaded file prison-population-270712.xls to data/raw/2012/
# Downloaded file prison-population-200712.xls to data/raw/2012/
# Downloaded file prison-population-13-07-12.xls to data/raw/2012/
# Downloaded file prison-population-060712.xls to data/raw/2012/
# Downloaded file prison-population-290612.xls to data/raw/2012/
# Downloaded file prison-population-220612.xls to data/raw/2012/
# Downloaded file prison-population-150612.xls to data/raw/2012/
# Downloaded file prison-population-080612.xls to data/raw/2012/
# Downloaded file prison-population-010612.xls to data/raw/2012/
# Downloaded file prison-population-25-may-2012.xls to data/raw/2012/
# Downloaded file prison-population-180512.xls to data/raw/2012/
# Downloaded file prison-population-110512.xls to data/raw/2012/
# Downloaded file prison-population-040512.xls to data/raw/2012/
# Downloaded file prison-population-270412.xls to data/raw/2012/
# Downloaded file prison-population-200412.xls to data/raw/2012/
# Downloaded file prison-population-130412.xls to data/raw/2012/
# Downloaded file prison-population-300312.xls to data/raw/2012/
# Downloaded file prison-population-230312.xls to data/raw/2012/
# Downloaded file prison-population-16-march-2012.xls to data/raw/2012/
# Downloaded file prison-population-090312.xls to data/raw/2012/
# Downloaded file prison-population-02-03-12.xls to data/raw/2012/
# Downloaded file prison-population-24-02-12.xls to data/raw/2012/
# Downloaded file prison-population-17-02-12.xls to data/raw/2012/
# Downloaded file prison-population-10-02-12.xls to data/raw/2012/
# Downloaded file prison-population-3-02-12.xls to data/raw/2012/
# Downloaded file prison-population-27-01-12.xls to data/raw/2012/
# Downloaded file prison-population-20-01-12.xls to data/raw/2012/
# Downloaded file prison-population-13-1-12.xls to data/raw/2012/
# Downloaded file prison-population-06-01-12.xls to data/raw/2012/

# %% [markdown]
# Great, that works. Now to move one level up so I can apply the `download_file` function to all of the years of data that I want.

# %% [markdown]
# ## Expanding to download data for multiple years

# %%
url = 'https://www.gov.uk/api/content/government/collections/prison-population-statistics'
response = requests.get(url)
response.json()
# Out:
# {'analytics_identifier': None,
#  'base_path': '/government/collections/prison-population-statistics',
#  'content_id': '5eb8ebe9-7631-11e4-a3cb-005056011aef',
#  'description': 'Statistics on the prison population.',
#  'details': {'body': '<div class="govspeak"><p>Statistics on the prison population.</p>\n</div>',
#   'change_history': [{'note': ' Prison population: weekly estate figures 2025 added. ',
#     'public_timestamp': '2025-01-06T15:18:12.000+00:00'},
#    {'note': 'Prison population figures: 2024  added',
#     'public_timestamp': '2024-01-05T11:25:00.000+00:00'},
#    {'note': 'Prison population figures: 2023 published.',
#     'public_timestamp': '2023-01-06T10:56:24.000+00:00'},
#    {'note': '2015 page added',
#     'public_timestamp': '2015-01-02T11:24:44.000+00:00'},
#    {'note': 'First published.',
#     'public_timestamp': '2013-10-18T00:00:00.000+01:00'}],
#   'collection_groups': [{'body': '<div class="govspeak">\n</div>',
#     'documents': ['edd0df70-cd64-4f90-958e-bd7717d8e445',
#      'dff9e4c8-7845-417e-8798-1955bc3655f5',
#      'ac72134b-f3dc-4f53-8a8a-5a7c36baa72c',
#      '061b110e-3011-4c56-87ca-1667656bebac',
#      'fb3c8bc1-57a4-4811-b36f-8bb583d005a4',
#      '786ac647-c3ad-44ca-a4af-e0bd1653f54b',
#      '040bb48e-5f4a-4b7e-9312-24650e0e4a75',
#      '590cf1b6-ad33-40d9-a362-33f064518ca9',
#      '4281eb4c-f0d7-40b5-9013-e52b7a28fff3',
#      'f308d536-fd5f-4654-9c43-73e09354bb5a',
#      'a2317d16-012d-4aa4-9f32-b3c281b14364',
#      '786faa40-6ee7-4171-91d8-1007becac892',
#      '5ef61d4c-7631-11e4-a3cb-005056011aef',
#      '5dc716ae-7631-11e4-a3cb-005056011aef',
#      '5dc71785-7631-11e4-a3cb-005056011aef',
#      '5dc716fe-7631-11e4-a3cb-005056011aef',
#      '5dc71616-7631-11e4-a3cb-005056011aef'],
#     'title': 'Documents'}],
#   'emphasised_organisations': ['dcc907d6-433c-42df-9ffb-d9c68be5dc4d'],
#   'first_public_at': '2013-10-18T00:00:00.000+01:00',
#   'political': False},
#  'document_type': 'document_collection',
#  'first_published_at': '2013-10-18T00:00:00+01:00',
#  'links': {'available_translations': [{'api_path': '/api/content/government/collections/prison-population-statistics',
#     'api_url': 'https://www.gov.uk/api/content/government/collections/prison-population-statistics',
#     'base_path': '/government/collections/prison-population-statistics',
#     'content_id': '5eb8ebe9-7631-11e4-a3cb-005056011aef',
#     'document_type': 'document_collection',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2025-01-06T15:18:12Z',
#     'schema_name': 'document_collection',
#     'title': 'Prison population statistics',
#     'web_url': 'https://www.gov.uk/government/collections/prison-population-statistics',
#     'withdrawn': False}],
#   'documents': [{'api_path': '/api/content/government/publications/prison-population-weekly-estate-figures-2025',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-weekly-estate-figures-2025',
#     'base_path': '/government/publications/prison-population-weekly-estate-figures-2025',
#     'content_id': 'edd0df70-cd64-4f90-958e-bd7717d8e445',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2025-02-03T11:43:39Z',
#     'schema_name': 'publication',
#     'title': 'Prison population: weekly estate figures 2025',
#     'web_url': 'https://www.gov.uk/government/publications/prison-population-weekly-estate-figures-2025',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/publications/prison-population-figures-2024',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2024',
#     'base_path': '/government/publications/prison-population-figures-2024',
#     'content_id': 'dff9e4c8-7845-417e-8798-1955bc3655f5',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2024-12-30T09:30:21Z',
#     'schema_name': 'publication',
#     'title': 'Prison population: weekly estate figures 2024',
#     'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2024',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/publications/prison-population-monthly-prison-figures-2024',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-monthly-prison-figures-2024',
#     'base_path': '/government/publications/prison-population-monthly-prison-figures-2024',
#     'content_id': 'ac72134b-f3dc-4f53-8a8a-5a7c36baa72c',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2025-01-10T10:55:22Z',
#     'schema_name': 'publication',
#     'title': 'Prison population: monthly prison figures 2024',
#     'web_url': 'https://www.gov.uk/government/publications/prison-population-monthly-prison-figures-2024',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/publications/prison-population-figures-2023',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2023',
#     'base_path': '/government/publications/prison-population-figures-2023',
#     'content_id': '061b110e-3011-4c56-87ca-1667656bebac',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2024-01-12T09:34:54Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2023',
#     'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2023',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/publications/prison-population-figures-2022',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2022',
#     'base_path': '/government/publications/prison-population-figures-2022',
#     'content_id': 'fb3c8bc1-57a4-4811-b36f-8bb583d005a4',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2023-01-13T09:40:47Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2022',
#     'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2022',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2021',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2021',
#     'base_path': '/government/statistics/prison-population-figures-2021',
#     'content_id': '786ac647-c3ad-44ca-a4af-e0bd1653f54b',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2022-01-14T09:40:19Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2021',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2021',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2020',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2020',
#     'base_path': '/government/statistics/prison-population-figures-2020',
#     'content_id': '040bb48e-5f4a-4b7e-9312-24650e0e4a75',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2021-01-08T14:59:49Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2020',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2020',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2019',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2019',
#     'base_path': '/government/statistics/prison-population-figures-2019',
#     'content_id': '590cf1b6-ad33-40d9-a362-33f064518ca9',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2020-01-10T08:55:27Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2019',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2019',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2018',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2018',
#     'base_path': '/government/statistics/prison-population-figures-2018',
#     'content_id': '4281eb4c-f0d7-40b5-9013-e52b7a28fff3',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2019-01-11T12:04:00Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2018',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2018',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2017',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2017',
#     'base_path': '/government/statistics/prison-population-figures-2017',
#     'content_id': 'f308d536-fd5f-4654-9c43-73e09354bb5a',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2018-01-15T11:58:07Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2017',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2017',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2016',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2016',
#     'base_path': '/government/statistics/prison-population-figures-2016',
#     'content_id': 'a2317d16-012d-4aa4-9f32-b3c281b14364',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2017-01-13T10:29:32Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2016',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2016',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2015',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2015',
#     'base_path': '/government/statistics/prison-population-figures-2015',
#     'content_id': '786faa40-6ee7-4171-91d8-1007becac892',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2016-01-08T10:40:50Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2015',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2015',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures-2014',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2014',
#     'base_path': '/government/statistics/prison-population-figures-2014',
#     'content_id': '5ef61d4c-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2015-01-09T12:16:48Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2014',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2014',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-figures',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures',
#     'base_path': '/government/statistics/prison-population-figures',
#     'content_id': '5dc716ae-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2014-01-10T10:11:22Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2013',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-2012',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2012',
#     'base_path': '/government/statistics/prison-population-2012',
#     'content_id': '5dc71785-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2013-01-11T00:00:00Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2012',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-2012',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/prison-population-2011',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2011',
#     'base_path': '/government/statistics/prison-population-2011',
#     'content_id': '5dc716fe-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2012-12-28T00:00:00Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2011',
#     'web_url': 'https://www.gov.uk/government/statistics/prison-population-2011',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistics/population-in-custody',
#     'api_url': 'https://www.gov.uk/api/content/government/statistics/population-in-custody',
#     'base_path': '/government/statistics/population-in-custody',
#     'content_id': '5dc71616-7631-11e4-a3cb-005056011aef',
#     'document_type': 'official_statistics',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2010-09-30T00:00:00Z',
#     'schema_name': 'publication',
#     'title': 'Population in custody: Jan 2009 to Aug 2010',
#     'web_url': 'https://www.gov.uk/government/statistics/population-in-custody',
#     'withdrawn': False}],
#   'government': [{'api_path': '/api/content/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government',
#     'api_url': 'https://www.gov.uk/api/content/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government',
#     'base_path': '/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government',
#     'content_id': '591c83aa-3b74-437d-a342-612bddd97572',
#     'details': {'current': False,
#      'ended_on': '2015-05-08T00:00:00+00:00',
#      'started_on': '2010-05-12T00:00:00+00:00'},
#     'document_type': 'government',
#     'links': {},
#     'locale': 'en',
#     'title': '2010 to 2015 Conservative and Liberal Democrat coalition government',
#     'web_url': 'https://www.gov.uk/government/2010-to-2015-conservative-and-liberal-democrat-coalition-government'}],
#   'organisations': [{'analytics_identifier': 'D18',
#     'api_path': '/api/content/government/organisations/ministry-of-justice',
#     'api_url': 'https://www.gov.uk/api/content/government/organisations/ministry-of-justice',
#     'base_path': '/government/organisations/ministry-of-justice',
#     'content_id': 'dcc907d6-433c-42df-9ffb-d9c68be5dc4d',
#     'details': {'acronym': 'MOJ',
#      'brand': 'ministry-of-justice',
#      'default_news_image': {'high_resolution_url': 'https://assets.publishing.service.gov.uk/media/5a37db21ed915d5a62fdc762/s960_ministry-of-justice.jpg',
#       'url': 'https://assets.publishing.service.gov.uk/media/5a37db21e5274a7908e352d9/s300_ministry-of-justice.jpg'},
#      'logo': {'crest': 'single-identity',
#       'formatted_title': 'Ministry<br/>of Justice'},
#      'organisation_govuk_status': {'status': 'live',
#       'updated_at': None,
#       'url': None}},
#     'document_type': 'organisation',
#     'links': {},
#     'locale': 'en',
#     'schema_name': 'organisation',
#     'title': 'Ministry of Justice',
#     'web_url': 'https://www.gov.uk/government/organisations/ministry-of-justice',
#     'withdrawn': False}],
#   'original_primary_publishing_organisation': [{'analytics_identifier': 'D18',
#     'api_path': '/api/content/government/organisations/ministry-of-justice',
#     'api_url': 'https://www.gov.uk/api/content/government/organisations/ministry-of-justice',
#     'base_path': '/government/organisations/ministry-of-justice',
#     'content_id': 'dcc907d6-433c-42df-9ffb-d9c68be5dc4d',
#     'details': {'acronym': 'MOJ',
#      'brand': 'ministry-of-justice',
#      'default_news_image': {'high_resolution_url': 'https://assets.publishing.service.gov.uk/media/5a37db21ed915d5a62fdc762/s960_ministry-of-justice.jpg',
#       'url': 'https://assets.publishing.service.gov.uk/media/5a37db21e5274a7908e352d9/s300_ministry-of-justice.jpg'},
#      'logo': {'crest': 'single-identity',
#       'formatted_title': 'Ministry<br/>of Justice'},
#      'organisation_govuk_status': {'status': 'live',
#       'updated_at': None,
#       'url': None}},
#     'document_type': 'organisation',
#     'links': {},
#     'locale': 'en',
#     'schema_name': 'organisation',
#     'title': 'Ministry of Justice',
#     'web_url': 'https://www.gov.uk/government/organisations/ministry-of-justice',
#     'withdrawn': False}],
#   'primary_publishing_organisation': [{'analytics_identifier': 'D18',
#     'api_path': '/api/content/government/organisations/ministry-of-justice',
#     'api_url': 'https://www.gov.uk/api/content/government/organisations/ministry-of-justice',
#     'base_path': '/government/organisations/ministry-of-justice',
#     'content_id': 'dcc907d6-433c-42df-9ffb-d9c68be5dc4d',
#     'details': {'acronym': 'MOJ',
#      'brand': 'ministry-of-justice',
#      'default_news_image': {'high_resolution_url': 'https://assets.publishing.service.gov.uk/media/5a37db21ed915d5a62fdc762/s960_ministry-of-justice.jpg',
#       'url': 'https://assets.publishing.service.gov.uk/media/5a37db21e5274a7908e352d9/s300_ministry-of-justice.jpg'},
#      'logo': {'crest': 'single-identity',
#       'formatted_title': 'Ministry<br/>of Justice'},
#      'organisation_govuk_status': {'status': 'live',
#       'updated_at': None,
#       'url': None}},
#     'document_type': 'organisation',
#     'links': {},
#     'locale': 'en',
#     'schema_name': 'organisation',
#     'title': 'Ministry of Justice',
#     'web_url': 'https://www.gov.uk/government/organisations/ministry-of-justice',
#     'withdrawn': False}],
#   'suggested_ordered_related_items': [{'api_path': '/api/content/government/publications/prison-population-figures-2022',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2022',
#     'base_path': '/government/publications/prison-population-figures-2022',
#     'content_id': 'fb3c8bc1-57a4-4811-b36f-8bb583d005a4',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2023-01-13T09:40:47Z',
#     'schema_name': 'publication',
#     'title': 'Prison population figures: 2022',
#     'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2022',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/publications/ome-review-body-members-register-of-interests',
#     'api_url': 'https://www.gov.uk/api/content/government/publications/ome-review-body-members-register-of-interests',
#     'base_path': '/government/publications/ome-review-body-members-register-of-interests',
#     'content_id': 'f888241c-6583-4cba-91ae-cc9815d72b0c',
#     'document_type': 'transparency',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2024-12-24T13:43:30Z',
#     'schema_name': 'publication',
#     'title': 'Review Body Members: register of interests',
#     'web_url': 'https://www.gov.uk/government/publications/ome-review-body-members-register-of-interests',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/statistical-data-sets/wholesale-fruit-and-vegetable-prices-weekly-average',
#     'api_url': 'https://www.gov.uk/api/content/government/statistical-data-sets/wholesale-fruit-and-vegetable-prices-weekly-average',
#     'base_path': '/government/statistical-data-sets/wholesale-fruit-and-vegetable-prices-weekly-average',
#     'content_id': '89de6246-23f1-4152-8ee0-0a79e7e93fd3',
#     'document_type': 'statistical_data_set',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2025-02-03T09:30:05Z',
#     'schema_name': 'statistical_data_set',
#     'title': 'Wholesale fruit and vegetable prices',
#     'web_url': 'https://www.gov.uk/government/statistical-data-sets/wholesale-fruit-and-vegetable-prices-weekly-average',
#     'withdrawn': False},
#    {'api_path': '/api/content/guidance/data-element-23-documents-and-other-reference-codes-national-of-the-customs-declaration-service-cds',
#     'api_url': 'https://www.gov.uk/api/content/guidance/data-element-23-documents-and-other-reference-codes-national-of-the-customs-declaration-service-cds',
#     'base_path': '/guidance/data-element-23-documents-and-other-reference-codes-national-of-the-customs-declaration-service-cds',
#     'content_id': '91c07616-b9dd-458d-b83b-f2b35fdc1fbc',
#     'document_type': 'detailed_guide',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2025-02-05T00:15:01Z',
#     'schema_name': 'detailed_guide',
#     'title': 'Data Element 2/3 Documents and Other Reference Codes (National) of the Customs Declaration Service (CDS)',
#     'web_url': 'https://www.gov.uk/guidance/data-element-23-documents-and-other-reference-codes-national-of-the-customs-declaration-service-cds',
#     'withdrawn': False},
#    {'api_path': '/api/content/government/collections/armed-force-corporate-covenant-signed-pledges',
#     'api_url': 'https://www.gov.uk/api/content/government/collections/armed-force-corporate-covenant-signed-pledges',
#     'base_path': '/government/collections/armed-force-corporate-covenant-signed-pledges',
#     'content_id': '5fdda0dc-7631-11e4-a3cb-005056011aef',
#     'document_type': 'document_collection',
#     'links': {},
#     'locale': 'en',
#     'public_updated_at': '2024-02-20T13:49:38Z',
#     'schema_name': 'document_collection',
#     'title': 'Businesses who have signed the Armed Forces Covenant',
#     'web_url': 'https://www.gov.uk/government/collections/armed-force-corporate-covenant-signed-pledges',
#     'withdrawn': False}],
#   'taxons': [{'api_path': '/api/content/crime-justice-and-law/justice-system-transparency',
#     'api_url': 'https://www.gov.uk/api/content/crime-justice-and-law/justice-system-transparency',
#     'base_path': '/crime-justice-and-law/justice-system-transparency',
#     'content_id': 'afd65c1c-dee0-4f5b-8bd6-4f502e4870af',
#     'details': {'internal_name': 'Justice system transparency [P]',
#      'notes_for_editors': '',
#      'visible_to_departmental_editors': False},
#     'document_type': 'taxon',
#     'links': {'parent_taxons': [{'api_path': '/api/content/crime-justice-and-law',
#        'api_url': 'https://www.gov.uk/api/content/crime-justice-and-law',
#        'base_path': '/crime-justice-and-law',
#        'content_id': 'ba951b09-5146-43be-87af-44075eac3ae9',
#        'description': '',
#        'details': {'internal_name': 'Crime, justice and law',
#         'notes_for_editors': '',
#         'visible_to_departmental_editors': True},
#        'document_type': 'taxon',
#        'links': {'root_taxon': [{'api_path': '/api/content/',
#           'api_url': 'https://www.gov.uk/api/content/',
#           'base_path': '/',
#           'content_id': 'f3bbdec2-0e62-4520-a7fd-6ffd5d36e03a',
#           'document_type': 'homepage',
#           'links': {},
#           'locale': 'en',
#           'public_updated_at': '2023-06-28T09:32:34Z',
#           'schema_name': 'homepage',
#           'title': 'GOV.UK homepage',
#           'web_url': 'https://www.gov.uk/',
#           'withdrawn': False}]},
#        'locale': 'en',
#        'phase': 'live',
#        'public_updated_at': '2018-09-16T20:34:51Z',
#        'schema_name': 'taxon',
#        'title': 'Crime, justice and law',
#        'web_url': 'https://www.gov.uk/crime-justice-and-law',
#        'withdrawn': False}]},
#     'locale': 'en',
#     'phase': 'live',
#     'public_updated_at': '2018-09-05T16:15:52Z',
#     'schema_name': 'taxon',
#     'title': 'Justice system transparency',
#     'web_url': 'https://www.gov.uk/crime-justice-and-law/justice-system-transparency',
#     'withdrawn': False}]},
#  'locale': 'en',
#  'phase': 'live',
#  'public_updated_at': '2025-01-06T15:18:12+00:00',
#  'publishing_app': 'whitehall',
#  'publishing_request_id': '21-1736176692.053-10.13.21.43-2172',
#  'publishing_scheduled_at': None,
#  'rendering_app': 'government-frontend',
#  'scheduled_publishing_delay_seconds': None,
#  'schema_name': 'document_collection',
#  'title': 'Prison population statistics',
#  'updated_at': '2025-02-05T00:15:02+00:00',
#  'withdrawn_notice': {}}

# %%
response.json()['links']['documents']
# Out:
# [{'api_path': '/api/content/government/publications/prison-population-weekly-estate-figures-2025',
#   'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-weekly-estate-figures-2025',
#   'base_path': '/government/publications/prison-population-weekly-estate-figures-2025',
#   'content_id': 'edd0df70-cd64-4f90-958e-bd7717d8e445',
#   'document_type': 'transparency',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2025-02-03T11:43:39Z',
#   'schema_name': 'publication',
#   'title': 'Prison population: weekly estate figures 2025',
#   'web_url': 'https://www.gov.uk/government/publications/prison-population-weekly-estate-figures-2025',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/publications/prison-population-figures-2024',
#   'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2024',
#   'base_path': '/government/publications/prison-population-figures-2024',
#   'content_id': 'dff9e4c8-7845-417e-8798-1955bc3655f5',
#   'document_type': 'transparency',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2024-12-30T09:30:21Z',
#   'schema_name': 'publication',
#   'title': 'Prison population: weekly estate figures 2024',
#   'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2024',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/publications/prison-population-monthly-prison-figures-2024',
#   'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-monthly-prison-figures-2024',
#   'base_path': '/government/publications/prison-population-monthly-prison-figures-2024',
#   'content_id': 'ac72134b-f3dc-4f53-8a8a-5a7c36baa72c',
#   'document_type': 'transparency',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2025-01-10T10:55:22Z',
#   'schema_name': 'publication',
#   'title': 'Prison population: monthly prison figures 2024',
#   'web_url': 'https://www.gov.uk/government/publications/prison-population-monthly-prison-figures-2024',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/publications/prison-population-figures-2023',
#   'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2023',
#   'base_path': '/government/publications/prison-population-figures-2023',
#   'content_id': '061b110e-3011-4c56-87ca-1667656bebac',
#   'document_type': 'transparency',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2024-01-12T09:34:54Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2023',
#   'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2023',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/publications/prison-population-figures-2022',
#   'api_url': 'https://www.gov.uk/api/content/government/publications/prison-population-figures-2022',
#   'base_path': '/government/publications/prison-population-figures-2022',
#   'content_id': 'fb3c8bc1-57a4-4811-b36f-8bb583d005a4',
#   'document_type': 'transparency',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2023-01-13T09:40:47Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2022',
#   'web_url': 'https://www.gov.uk/government/publications/prison-population-figures-2022',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2021',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2021',
#   'base_path': '/government/statistics/prison-population-figures-2021',
#   'content_id': '786ac647-c3ad-44ca-a4af-e0bd1653f54b',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2022-01-14T09:40:19Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2021',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2021',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2020',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2020',
#   'base_path': '/government/statistics/prison-population-figures-2020',
#   'content_id': '040bb48e-5f4a-4b7e-9312-24650e0e4a75',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2021-01-08T14:59:49Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2020',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2020',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2019',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2019',
#   'base_path': '/government/statistics/prison-population-figures-2019',
#   'content_id': '590cf1b6-ad33-40d9-a362-33f064518ca9',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2020-01-10T08:55:27Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2019',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2019',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2018',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2018',
#   'base_path': '/government/statistics/prison-population-figures-2018',
#   'content_id': '4281eb4c-f0d7-40b5-9013-e52b7a28fff3',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2019-01-11T12:04:00Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2018',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2018',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2017',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2017',
#   'base_path': '/government/statistics/prison-population-figures-2017',
#   'content_id': 'f308d536-fd5f-4654-9c43-73e09354bb5a',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2018-01-15T11:58:07Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2017',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2017',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2016',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2016',
#   'base_path': '/government/statistics/prison-population-figures-2016',
#   'content_id': 'a2317d16-012d-4aa4-9f32-b3c281b14364',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2017-01-13T10:29:32Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2016',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2016',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2015',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2015',
#   'base_path': '/government/statistics/prison-population-figures-2015',
#   'content_id': '786faa40-6ee7-4171-91d8-1007becac892',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2016-01-08T10:40:50Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2015',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2015',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures-2014',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2014',
#   'base_path': '/government/statistics/prison-population-figures-2014',
#   'content_id': '5ef61d4c-7631-11e4-a3cb-005056011aef',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2015-01-09T12:16:48Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2014',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures-2014',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-figures',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-figures',
#   'base_path': '/government/statistics/prison-population-figures',
#   'content_id': '5dc716ae-7631-11e4-a3cb-005056011aef',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2014-01-10T10:11:22Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2013',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-figures',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-2012',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2012',
#   'base_path': '/government/statistics/prison-population-2012',
#   'content_id': '5dc71785-7631-11e4-a3cb-005056011aef',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2013-01-11T00:00:00Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2012',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-2012',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/prison-population-2011',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/prison-population-2011',
#   'base_path': '/government/statistics/prison-population-2011',
#   'content_id': '5dc716fe-7631-11e4-a3cb-005056011aef',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2012-12-28T00:00:00Z',
#   'schema_name': 'publication',
#   'title': 'Prison population figures: 2011',
#   'web_url': 'https://www.gov.uk/government/statistics/prison-population-2011',
#   'withdrawn': False},
#  {'api_path': '/api/content/government/statistics/population-in-custody',
#   'api_url': 'https://www.gov.uk/api/content/government/statistics/population-in-custody',
#   'base_path': '/government/statistics/population-in-custody',
#   'content_id': '5dc71616-7631-11e4-a3cb-005056011aef',
#   'document_type': 'official_statistics',
#   'links': {},
#   'locale': 'en',
#   'public_updated_at': '2010-09-30T00:00:00Z',
#   'schema_name': 'publication',
#   'title': 'Population in custody: Jan 2009 to Aug 2010',
#   'web_url': 'https://www.gov.uk/government/statistics/population-in-custody',
#   'withdrawn': False}]

# %%
response.json()['links']['documents'][0]['api_url']
# Out:
# 'https://www.gov.uk/api/content/government/publications/prison-population-weekly-estate-figures-2025'

# %%
url = 'https://www.gov.uk/api/content/government/collections/prison-population-statistics'
response = requests.get(url)
data = response.json()
documents = response.json()['links']['documents']

# Create list of API URLs for each year of prison population statistics
api_urls = [document['api_url'] for document in documents]
api_urls
# Out:
# ['https://www.gov.uk/api/content/government/publications/prison-population-weekly-estate-figures-2025',
#  'https://www.gov.uk/api/content/government/publications/prison-population-figures-2024',
#  'https://www.gov.uk/api/content/government/publications/prison-population-monthly-prison-figures-2024',
#  'https://www.gov.uk/api/content/government/publications/prison-population-figures-2023',
#  'https://www.gov.uk/api/content/government/publications/prison-population-figures-2022',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2021',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2020',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2019',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2018',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2017',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2016',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2015',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures-2014',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-figures',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-2012',
#  'https://www.gov.uk/api/content/government/statistics/prison-population-2011',
#  'https://www.gov.uk/api/content/government/statistics/population-in-custody']

# %% [markdown]
# ### Downloading multiple years

# %%
test_urls = api_urls[:2]
test_urls
# Out:
# ['https://www.gov.uk/api/content/government/publications/prison-population-weekly-estate-figures-2025',
#  'https://www.gov.uk/api/content/government/publications/prison-population-figures-2024']

# %%
with ThreadPoolExecutor() as executor:
    executor.map(download_file, test_urls)
# Out:
# Downloaded file prison-pop-3-feb-2025.ods to data/raw/2025/
# Downloaded file PSWEBREPORT_30_December.ods to data/raw/2024/
# Downloaded file prison-pop-27-jan-2025.ods to data/raw/2025/
# Downloaded file 23_December_2024.ods to data/raw/2024/
# Downloaded file prison-pop-20-jan-2025.ods to data/raw/2025/
# Downloaded file prison-pop-16-dec-2024.ods to data/raw/2024/
# Downloaded file prison-pop-13-january-2025.ods to data/raw/2025/
# Downloaded file prison_pop__dec_24.ods to data/raw/2024/
# Downloaded file 6_January_PSWEBREPORT.ods to data/raw/2025/
# Download complete!
# Downloaded file prison-pop-2-dec-2024.ods to data/raw/2024/
# Downloaded file prison-pop-25-nov-2024.ods to data/raw/2024/
# Downloaded file prison-pop-18-nov-2024.ods to data/raw/2024/
# Downloaded file prison-pop-11-nov-2024.ods to data/raw/2024/
# Downloaded file prison-pop-4-november-2024.ods to data/raw/2024/
# Downloaded file Prison_stats_28_October.ods to data/raw/2024/
# Downloaded file Prison_stats_weekly_21_October_2024.ods to data/raw/2024/
# Downloaded file Ad_hoc_release_-_July_2024_to_October_2024_Monday_Adult_Male_population_data.xlsx to data/raw/2024/
# Downloaded file prison-pop-18-october-2024.ods to data/raw/2024/
# Downloaded file prison-pop-11-oct-2024.ods to data/raw/2024/
# Downloaded file prison-pop-4-october-2024.ods to data/raw/2024/
# Downloaded file prison-pop-27-sept-2024.ods to data/raw/2024/
# Downloaded file prison-pop-20-sept-2024.ods to data/raw/2024/
# Downloaded file prison-pop-13-sept-2024.ods to data/raw/2024/
# Downloaded file prison-pop-6-sept-2024.ods to data/raw/2024/
# Downloaded file Prison_population_30_August.ods to data/raw/2024/
# Downloaded file Prison_population_23_August.ods to data/raw/2024/
# Downloaded file prison-pop-16-aug-2024.ods to data/raw/2024/
# Downloaded file prison-pop-9-aug-2024.ods to data/raw/2024/
# Downloaded file prison-pop-2-aug-2024.ods to data/raw/2024/
# Downloaded file Population_bulletin_weekly_26_July_2024_.ods to data/raw/2024/
# Downloaded file population_19_July_2024.ods to data/raw/2024/
# Downloaded file prison-pop-12-july-2024.ods.ods to data/raw/2024/
# Downloaded file prison-pop-5-july-2024.ods to data/raw/2024/
# Downloaded file prison-pop-28-june-2024.ods to data/raw/2024/
# Downloaded file prison-pop-21-june-2024.ods to data/raw/2024/
# Downloaded file prison-pop-14-june-2024.ods to data/raw/2024/
# Downloaded file prison-pop-7-june-2024.ods to data/raw/2024/
# Downloaded file prison-population-31-May.ods to data/raw/2024/
# Downloaded file prison-pop-24-may-2024.ods to data/raw/2024/
# Downloaded file prison-pop-17-may-2024.ods to data/raw/2024/
# Downloaded file prison-pop-10-may-2024.ods to data/raw/2024/
# Downloaded file prison-pop-3-may-2024.ods to data/raw/2024/
# Downloaded file prison-pop-26-apr-2024.ods to data/raw/2024/
# Downloaded file prison-pop-19-april-2024.ods to data/raw/2024/
# Downloaded file PSWEBREPORT_12_April.ods to data/raw/2024/
# Downloaded file prison-pop-5-april-2024.ods to data/raw/2024/
# Downloaded file prison-pop-22-march-2024.ods to data/raw/2024/
# Downloaded file prison-pop-15-march-2024.ods to data/raw/2024/
# Downloaded file prison-pop-8-march-2024.ods to data/raw/2024/
# Downloaded file prison-pop-1-march-2024.ods to data/raw/2024/
# Downloaded file Prison_population_report_23_Feb_24.ods to data/raw/2024/
# Downloaded file prison-pop-16-feb-2024.ods to data/raw/2024/
# Downloaded file prison-pop-9-feb-2024.ods to data/raw/2024/
# Downloaded file prison-pop-2-february-2024.ods to data/raw/2024/
# Downloaded file prison-pop-26-jan-2024.ods to data/raw/2024/
# Downloaded file prison-pop-19-jan-2024.ods to data/raw/2024/
# Downloaded file prison-pop-12-jan-2024.ods to data/raw/2024/
# Downloaded file PSWEBREPORT.ods to data/raw/2024/
# Download complete!
